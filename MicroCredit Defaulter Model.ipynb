# %%
import pandas as pd
#import pandas.plotting._core.PlotAccessor
import pandas.plotting as  pl

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.figure as fig
import seaborn as sns
#import sklearn.preprocessing.LabelEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel('micro.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  ...  \
# 0    220.13    260.13                2.0                0.0  ...
# 1   3691.26   3691.26               20.0                0.0  ...
# 2    900.13    900.13                3.0                0.0  ...
# 3    159.42    159.42               41.0                0.0  ...
# 4   1098.90   1098.90                4.0                0.0  ...
#
#    maxamnt_loans30  medianamnt_loans30  cnt_loans90  amnt_loans90  \
# 0              6.0                 0.0          2.0            12
# ...

# %%
df.shape
# Out:
# (209593, 37)

# %%
df.drop("Unnamed: 0", axis = 1, inplace = True)

# %%
df.drop("pcircle",axis=1,inplace=True)

# %%
df.drop("pdate",axis=1,inplace=True)

# %%
df.head()
# Out:
#    label       msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0  21408I70789  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  76462I70374  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1  17943I70372  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  55773I70781  241.0     21.228000     21.228000    159.42    159.42
# 4      1  03813I82730  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  ...  cnt_loans30  \
# 0                2.0                0.0              1539  ...            2
# 1               20.0                0.0              5787  ...            1
# 2                3.0                0.0              1539  ...            1
# 3               41.0                0.0               947  ...            2
# 4                4.0                0.0              2309  ...            7
#
# ...

# %%
for column in df.columns:
    if df[column].dtype == object:
        print(str(column) + ":" + str(df[column].unique()))
        print(df[column].value_counts())
        print("-----------------------------")
# Out:
# msisdn:['21408I70789' '76462I70374' '17943I70372' ... '22758I85348' '59712I82733'
#  '65061I85339']
# 04581I85330    7
# 47819I90840    7
# 43430I70786    6
# 29191I82738    6
# 55809I89238    6
#               ..
# 06579I95203    1
# 81519I90585    1
# 07630I70377    1
# 74217I82733    1
# 37223I95202    1
# Name: msisdn, Length: 186243, dtype: int64
# -----------------------------

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90'],
#       dtype='object')

# %% [markdown]
# # Visualization

# %%
sns.distplot(df["label"])
# Out:
# <AxesSubplot:xlabel='label', ylabel='Density'>

# %%
sns.distplot(df["aon"])
# Out:
# <AxesSubplot:xlabel='aon', ylabel='Density'>

# %%
sns.distplot(df["daily_decr30"])
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='Density'>

# %%
sns.distplot(df["daily_decr90"])
# Out:
# <AxesSubplot:xlabel='daily_decr90', ylabel='Density'>

# %%
sns.distplot(df["rental30"])
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='Density'>

# %%
sns.distplot(df["rental90"])
# Out:
# <AxesSubplot:xlabel='rental90', ylabel='Density'>

# %%
sns.distplot(df["last_rech_date_ma"])
# Out:
# <AxesSubplot:xlabel='last_rech_date_ma', ylabel='Density'>

# %%
sns.distplot(df["last_rech_date_da"])
# Out:
# <AxesSubplot:xlabel='last_rech_date_da', ylabel='Density'>

# %%
sns.distplot(df["last_rech_amt_ma"])
# Out:
# <AxesSubplot:xlabel='last_rech_amt_ma', ylabel='Density'>

# %%
sns.distplot(df["cnt_ma_rech30"])
# Out:
# <AxesSubplot:xlabel='cnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df["fr_ma_rech30"])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df["sumamnt_ma_rech30"])
# Out:
# <AxesSubplot:xlabel='sumamnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df["medianamnt_ma_rech30"])
# Out:
# <AxesSubplot:xlabel='medianamnt_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df["medianmarechprebal30"])
# Out:
# <AxesSubplot:xlabel='medianmarechprebal30', ylabel='Density'>

# %%
sns.distplot(df["amnt_loans30"])
# Out:
# <AxesSubplot:xlabel='amnt_loans30', ylabel='Density'>

# %%
sns.distplot(df["maxamnt_loans30"])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans30', ylabel='Density'>

# %%
sns.distplot(df["medianamnt_loans30"])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans30', ylabel='Density'>

# %%
sns.distplot(df["cnt_loans90"])
# Out:
# <AxesSubplot:xlabel='cnt_loans90', ylabel='Density'>

# %%
sns.distplot(df["amnt_loans90"])
# Out:
# <AxesSubplot:xlabel='amnt_loans90', ylabel='Density'>

# %%
sns.distplot(df["maxamnt_loans90"])
# Out:
# <AxesSubplot:xlabel='maxamnt_loans90', ylabel='Density'>

# %%
sns.distplot(df["medianamnt_loans90"])
# Out:
# <AxesSubplot:xlabel='medianamnt_loans90', ylabel='Density'>

# %%
sns.distplot(df["fr_ma_rech30"])
# Out:
# <AxesSubplot:xlabel='fr_ma_rech30', ylabel='Density'>

# %%
sns.distplot(df["payback30"])
# Out:
# <AxesSubplot:xlabel='payback30', ylabel='Density'>

# %%
sns.distplot(df["payback90"])
# Out:
# <AxesSubplot:xlabel='payback90', ylabel='Density'>

# %% [markdown]
# # BoxPlot

# %%
df["label"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["aon"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["daily_decr30"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["rental30"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["rental90"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["cnt_ma_rech30"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["fr_ma_rech30"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["sumamnt_ma_rech30"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["medianamnt_ma_rech30"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["medianmarechprebal30"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["cnt_ma_rech90"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["sumamnt_ma_rech90"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["medianamnt_ma_rech90"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["medianmarechprebal90"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["cnt_da_rech30"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["fr_da_rech30"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["fr_da_rech90"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["maxamnt_loans90"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
df["payback90"].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
#view some statistics
df.describe()
# Out:
#                label         msisdn            aon   daily_decr30  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177       0.499891       0.008161       0.020579
# std         0.330519       0.288648       0.075703       0.034662
# min         0.000000       0.000000       0.000000       0.000000
# 25%         1.000000       0.249707       0.000294       0.000509
# 50%         1.000000       0.499742       0.000575       0.005872
# 75%         1.000000       0.749702       0.001030       0.027581
# max         1.000000       1.000000       1.000000       1.000000
#
#         daily_decr90       rental30       rental90  last_rech_date_ma  \
# count  209593.000000  209593.000000  209593.000000      209593.000000
# mean        0.019255       0.118698       0.125424           0.003790
# std         0.034044       0.019350       0.025661           0.053977
# min         0.000000       0.000000       0.000000           0.000000
# ...

# %% [markdown]
# # correlation

# %%
# check the correlation
df.corr()
# Out:
#                          label    msisdn       aon  daily_decr30  \
# label                 1.000000  0.001976 -0.003785      0.168298
# msisdn                0.001976  1.000000  0.000566      0.000717
# aon                  -0.003785  0.000566  1.000000      0.001104
# daily_decr30          0.168298  0.000717  0.001104      1.000000
# daily_decr90          0.166150  0.000950  0.000374      0.977704
# rental30              0.058085 -0.001404 -0.000960      0.442066
# rental90              0.075521 -0.000691 -0.000790      0.458977
# last_rech_date_ma     0.003728 -0.000928  0.001692      0.000487
# last_rech_date_da     0.001711  0.001400 -0.001693     -0.001636
# last_rech_amt_ma      0.169902 -0.001328  0.002537      0.288438
# cnt_ma_rech30         0.239192  0.000960 -0.003137      0.450652
# fr_ma_rech30          0.001330 -0.001804 -0.001163     -0.000577
# sumamnt_ma_rech30     0.186063  0.002633  0.000582      0.613200
# ...

# %%
plt.figure(figsize = (14,14))
sns.heatmap(df.corr(),annot = True, fmt = ".0%")
# Out:
# <AxesSubplot:>

# %% [markdown]
# # histogram

# %%
df.hist(figsize=(30,30),layout=(12,3),sharex=False)
# Out:
# array([[<AxesSubplot:title={'center':'label'}>,
#         <AxesSubplot:title={'center':'msisdn'}>,
#         <AxesSubplot:title={'center':'aon'}>],
#        [<AxesSubplot:title={'center':'daily_decr30'}>,
#         <AxesSubplot:title={'center':'daily_decr90'}>,
#         <AxesSubplot:title={'center':'rental30'}>],
#        [<AxesSubplot:title={'center':'rental90'}>,
#         <AxesSubplot:title={'center':'last_rech_date_ma'}>,
#         <AxesSubplot:title={'center':'last_rech_date_da'}>],
#        [<AxesSubplot:title={'center':'last_rech_amt_ma'}>,
#         <AxesSubplot:title={'center':'cnt_ma_rech30'}>,
#         <AxesSubplot:title={'center':'fr_ma_rech30'}>],
#        [<AxesSubplot:title={'center':'sumamnt_ma_rech30'}>,
#         <AxesSubplot:title={'center':'medianamnt_ma_rech30'}>,
#         <AxesSubplot:title={'center':'medianmarechprebal30'}>],
#        [<AxesSubplot:title={'center':'cnt_ma_rech90'}>,
#         <AxesSubplot:title={'center':'fr_ma_rech90'}>,
# ...

# %% [markdown]
# # Label Encoder

# %% [raw]
# Label encoder convert the string into numerical data

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for column in df.columns:
    if df[column].dtype == np.number:
        continue
    df[column] = LabelEncoder().fit_transform(df[column])

# %% [markdown]
# # MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
scaled_values = scaler.fit_transform(df) 
df.loc[:,:] = scaled_values

# %% [markdown]
# # Split the data into x and y variable

# %%
y=df.iloc[:,: 1]
y.head()
# Out:
#    label
# 0    0.0
# 1    1.0
# 2    1.0
# 3    1.0
# 4    1.0

# %%
x=df.iloc[: , 1:]
x.head()
# Out:
#      msisdn       aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0  0.215800  0.000320      0.011834      0.009847  0.107594  0.111090
# 1  0.764011  0.000760      0.045918      0.038094  0.123183  0.126349
# 2  0.180378  0.000583      0.005605      0.004649  0.110648  0.113936
# 3  0.559256  0.000289      0.000429      0.000356  0.107322  0.110642
# 4  0.037102  0.000995      0.000916      0.000760  0.111541  0.114820
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  ...  \
# 0           0.000031           0.000029          0.202899       0.028571  ...
# 1           0.000049           0.000029          0.550725       0.014286  ...
# 2           0.000032           0.000029          0.202899       0.014286  ...
# 3           0.000070           0.000029          0.144928       0.000000  ...
# 4           0.000033           0.000029          0.333333       0.100000  ...
#
#    cnt_loans30  amnt_loans30  maxamnt_loans30  medianamnt_loans30  \
# ...

# %% [markdown]
# # Split the data into Training and testing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=30, random_state= 0)

# %% [markdown]
# # LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression



lg = LogisticRegression() 
lg.fit(x_train,y_train)
lg.score(x_train,y_train)

pred=lg.predict(x_test)

from sklearn.metrics import accuracy_score
print(round(accuracy_score(y_test,pred),2))
# Out:
# 0.77

# %% [markdown]
# # metrics

# %%
from sklearn import metrics
print(metrics.classification_report(y_test, pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         7
#          1.0       0.77      1.00      0.87        23
#
#     accuracy                           0.77        30
#    macro avg       0.38      0.50      0.43        30
# weighted avg       0.59      0.77      0.67        30

# %% [markdown]
# # confusion matrix

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred))
print(metrics.classification_report(y_test, pred))
# Out:
# [[ 0  7]
#  [ 0 23]]
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00         7
#          1.0       0.77      1.00      0.87        23
#
#     accuracy                           0.77        30
#    macro avg       0.38      0.50      0.43        30
# weighted avg       0.59      0.77      0.67        30

# %% [markdown]
# # LinearRegression

# %%
from sklearn.linear_model import LinearRegression
# creating the Linear Regression model
lR = LinearRegression()
# putting the training data to the model
lR.fit(x_train, y_train)
y_pred_lR = lR.predict(x_test)
lR.score(x_train,y_train)
# Out:
# 0.11548346420957545

# %% [markdown]
# # RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=200)
rfc.fit(x_train,y_train)
y_pred2=rfc.predict(x_test)

# %%
rfc.score(x_train,y_train)
# Out:
# 0.9995609912055086

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred2))
print(classification_report(y_test,y_pred2))
# Out:
# [[ 2  5]
#  [ 3 20]]
#               precision    recall  f1-score   support
#
#          0.0       0.40      0.29      0.33         7
#          1.0       0.80      0.87      0.83        23
#
#     accuracy                           0.73        30
#    macro avg       0.60      0.58      0.58        30
# weighted avg       0.71      0.73      0.72        30

# %% [markdown]
# # GradientBoostingClassifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(x_train,y_train)
y_pred3=gbc.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred3))
print(classification_report(y_test,y_pred3))
# Out:
# [[ 1  6]
#  [ 1 22]]
#               precision    recall  f1-score   support
#
#          0.0       0.50      0.14      0.22         7
#          1.0       0.79      0.96      0.86        23
#
#     accuracy                           0.77        30
#    macro avg       0.64      0.55      0.54        30
# weighted avg       0.72      0.77      0.71        30

# %% [markdown]
# # DecisionTreeClassifier

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier()
clf = clf.fit(x_train,y_train)
y_pred1 = clf.predict(x_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred1))
print(classification_report(y_test,y_pred1))
# Out:
# [[ 3  4]
#  [ 2 21]]
#               precision    recall  f1-score   support
#
#          0.0       0.60      0.43      0.50         7
#          1.0       0.84      0.91      0.87        23
#
#     accuracy                           0.80        30
#    macro avg       0.72      0.67      0.69        30
# weighted avg       0.78      0.80      0.79        30

# %% [raw]
# conclusion is that random forest has 99 percentage accuracy lavel.
# so, we are going with the random forest.
